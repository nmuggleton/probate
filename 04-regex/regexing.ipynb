# %% [markdown]
# # Extract Data from .txt

# %% [markdown]
# ## Import packages

# %%
import string
import sys
from import_txts import *
import os
from glob import glob
import regex as re
import pandas as pd

# %% [markdown]
# ## Parameters

# %%
## Parameters
year = '1858'

# %% [markdown]
# ## Import files
# ### Make a list of images that are to be converted into text

# %%
image_path = glob('tesseract/' + year + '/*')
image_path.sort()

# %% [markdown]
# ### Import .txt files

# %%
pages = []

file = image_path
for f in file:
    s = open(f, "r").read()
    pages.append(s)

# %% [markdown]
# ## Clean unusual punctuation
#
# Probate records contain a small subset of punctuation marks. Weird characters are likely Tesseract trying to interpret squiggles of dust as characters, so should be removed.
#
# ### Symbols that I want to keep

# %%
punctuation = '.' + '-' + '—' + ',' + '(' + ')' + "'" + '‘' + '’' + '"' + '“' + '”'
whitelist = string.ascii_letters + string.digits + punctuation + ' ' + '\n' + '£'

# %% [markdown]
# ### Set comparison
#
# Empty lists and sets to store unique characters pre- and post-clean:

# %%
clean_pages = []
old_set = set()
new_set = set()

# %% [markdown]
# ### Remove characters that aren't on the whitelist

# %%
for page in pages:
    clean_string = ''
    for char in page:
        if char in whitelist:
            clean_string += char
        else:
            clean_string += ''
    clean_string = clean_string.replace('\‘|\’', "'")
    clean_string = clean_string.replace('\“|\”', '"')
    clean_string = clean_string.replace('\—', '-')
    clean_string = clean_string.replace('. .', '.')
    clean_pages.append(clean_string)
    old = set(page)
    new = set(clean_string)
    old_set = old_set | old
    new_set = new_set | new

# %% [markdown]
# ### Validation
#
# Quick check of removed characters. Do I want to keep any of these?

# %%
old_set - new_set
# Out:
# {'\x0c',
#  '!',
#  '#',
#  '$',
#  '%',
#  '&',
#  '*',
#  '+',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '_',
#  '{',
#  '|',
#  '}',
#  '~',
#  '¢',
#  '¥',
#  '§',
#  '©',
#  '«',
#  '®',
#  '°',
#  '»',
#  'é',
#  '€',
#  '™'}

# %% [markdown]
# ## Remove superfluous pages
#
# ### Canterbury court records
#
# *Note.* Only relevant for records in 1858. Prior to mid-January of that year, records were proved locally. Most of these cases were proved in Canterbury. As such, the records contain a few instances where we have lists of non-relevant data.
#
# We can remove these files by:
# 1. checking whether the file year is 1858, then
# 2. checking whether the page header indicates that it is in the legacy format

# %%
if year == '1858':
    clean_pages = [page for page in clean_pages if 'COURT OF CANTERBURY' not in page]
    clean_pages = [page for page in clean_pages if 'WILLS PROVED' not in page]
    clean_pages = [page for page in clean_pages if 'PROVED IN THE' not in page]
    clean_pages = [page for page in clean_pages if 'ADMINISTRATIONS GRANTED BY THE' not in page]

# %% [markdown]
# ### Scottish and Irish probate
#
# For simplicity, we will look at the wills proved in England and Wales. We can remove this line if we'd like to expand the analysis.

# %%
clean_pages = [page for page in clean_pages if 'SCOTCH CONFIRMATIONS' not in page]
clean_pages = [page for page in clean_pages if 'RISH PROBATES' not in page]

# %% [markdown]
# ### Appendices
#
# These are handwritten notes.

# %%
clean_pages = [page for page in clean_pages if 'APPENDIX' not in page]
clean_pages = [page for page in clean_pages if 'PBOLTIVTLD' not in page]

# %%
print(clean_pages[4])
# Out:
# 92
#
# ASHCROFT Robert.
# Effects under £600.
#
# ASHDOWN Sarah.
#
# Effects under £1,500.
#
# ASHDOWN William.
# Effects under £200.
#
# ASHER Hannah.
# Effects under £200.
#
# ASHER Rachel.
# Effects under £600.
#
# WILLS. 1858.
#
# “
#
# at Derby by the oaths of Henry Kerry of
# Spondon aforesaid Farmer and Isaac Potter
# of the same place Farmer the Executors.
#
# 9 November. The Will
#
# of Robert Ashcroft late of Bootle-cum-Linacre
# in the County of Lancaster Gardener
# deceased who died 22 October 1858 at
# Bootle-cum-Linacre aforesaid was proved at
# Liverpool by the oath of Robert Ashcroft
# of Orrell near Seaforth in the same County
# Labourer the Son and one of the Executors,
#
# 28 August. The Will
#
# with a Codicil of Sarah Ashdown formerly
# of 4 Regent-place West in the County of
# Middlesex and late of Lingfield in the County
# of Surrey Spinster deceased who died
# 17 May 1858 at Lingfield aforesaid was
# proved at the Principal Registry by the
# oaths of Faringdon Lane of 103 Southwark-
# bridge-road in the said County of Surrey
# Civil Engineer and Arthur James Lane of
# Surbiton in the same County Gentleman. the
# Executors.
#
# 18 March. The Will
#
# of William Ashdown late of Burgate-street in
# the City of Canterbury Stationer deceased
# who died 5 February 1858 at Burgate-street
# aforesaid was proved at Canterbury by the
# oath of Elizabeth Ashdown of Burgate-street
# aforesaid Widow the Relict and the sole
# Executrix.
#
# 26 October. The Will
#
# of Hannah Asher late of Beeston in the County
# of Nottingham Widow deceased who died
# 19 May 1858 at Beeston aforesaid was proved
# at Nottingham by the oath of Joseph Dore
# of Chilwell in the said County Beer-house
# Keeper the Executor according to the tenor of
# the said Will.
#
# Letters of Administration
# (with the Will annexed) of the Personal estate
# and effects of Rachel Asher formerly of
# Islington-street Salford in the County of
#
# Lancaster and late of Manchester in the.
#
# same County Widow deceased who died
# 27 December 1857 at Manchester aforesaid
# were granted at Manchester to Jeannette

# %% [markdown]
# ## Regex
# ### Page metadata
# Split page metadata from body of page.

# %% [markdown]
# #### Search strings

# %%
## page, probate, year
ppy = re.compile('(\d+\s+(WILLS|ADMINISTRATIONS).\s+%s.)' % year)
## probate, year, page
pyp = re.compile('((WILLS|ADMINISTRATIONS).\s+%s.\s+\d+)' % year)
# fuzzy page, probate, year
fuzz_ppy = re.compile('(\d+\s+(WILLS|ADMINISTRATIONS).\s+%s.){e<=2}' % year)
# fuzzy probate, year, page
fuzz_pyp = re.compile('((WILLS|ADMINISTRATIONS).\s+%s.\s+\d+){e<=2}' % year)
# page, gap, probate, year
pgpy = re.compile('(^\d+)(.*)((WILLS|ADMINISTRATIONS).)(\s+%s.)' % year)
# page in top right corner of page
page_no = re.compile('^\d+')
# page and year string
py = re.compile('(WILLS|ADMINISTRATIONS). %s.' % year)

# %% [markdown]
# #### Extraction

# %%
pages = []
probate_type = []
bodies = []

for p in clean_pages:
    
    try:
        page = re.search(ppy, p).group(0)
        
    except AttributeError:
        try:
            page = re.search(pyp, p).group(0)
            
        except AttributeError:
            try:
                pn = re.search(page_no, p).group(0)
                pys = re.search(py, p).group(0)
                page = pn + ' ' + pys
                
            except AttributeError:
                try:
                    page = re.search(fuzz_ppy, p).group(0)
                    
                except AttributeError:
                    try:
                        page = re.search(fuzz_pyp, p).group(0)
                        
                    except AttributeError:
                        page = None
                        body = page
    finally:
        if page != None:
            page = re.sub('\n', '', page)
            page = re.sub('\s+', ' ', page)
            try:
                body = re.sub(page, '', p)
            except:
                pass
            try:
                page_number = int(re.findall('(^\d+|\d+$)', page)[0])
            
            except:
                page_number = None
            
            will_or_admin = re.findall('[A-Z]+', page)[0]

        else:
            page_number = None
            body = p
            
        pages.append(page_number)
        probate_type.append(will_or_admin)
        bodies.append(body)

# %% [markdown]
# ### Names and effects
# #### Search strings

# %%
## regex pattern for names
surname_firstname = re.compile('([A-Z]+([\n\r\s]+[A-Z][a-z]+)+)')
compiled = re.compile('(Effects under £\d+){e<=2}')

# %% [markdown]
# #### Extraction

# %%
name_effs = []

for body in bodies:

# %%
name_effs = {}
name_effs['name'] = []
name_effs['effects'] = []

for body in bodies[:2]: ## For each page in a year
    bodies_split = re.split('\n\n', body)

    page_names = []
    page_effects = []

    for bod in bodies_split: # for each line in a page
        try:
            n = re.search(surname_firstname, bod).group(0)
            page_names.append(n)
            
        except AttributeError:
            try:
                e = re.search(compiled, bod).group(0)
                page_effects.append(e)
                
            except AttributeError:
                pass
    
    if len(page_names) == len(page_effects):
        print('yay')
    else:
        print('oops')
    name_effs['name'].append(page_names)
    name_effs['effects'].append(page_effects)
# Out:
# oops
# oops

# %%
re.search('^[A-Z]+([\n\r\s]+[A-Z][a-z]+)+', 'otherwise\n\nASBRIDGE\nEffects under £1,000,\n\nASHBRIDGE\n Jane.\n')
bodies_split
# b = re.split('\n', body)
# names_and_effects = list(filter(surname_firstname.match, b))

# %%
months = '(January|February|March|April|May|June|July|August|September|October|November|December)'

calendar = re.compile('(\d+\s+%s\.){e<=1}' % months)
re.search(calendar, body).group()

print(bodies[0])
# Out:
# ARTHUR James.
# Effects under £450.
#
# ARTISS James Benjamin.
# Effects under £50.
#
# otherwise
#
# ASHBRIDGE
# is ane.
# ASBRIDGE
#
# ASBURY William.
# Effects under £300.
#
# ASH Elizabeth.
# Effects under £20.
#
# ASH Isaac.
# Effects under £100.
#
# 29 January.
#
# 12 June.
#
# 1 June.
#
# 14 December.
#
# 15 September.
#
# The Will
# of James Arthur late of the Parish of
# Egloshayle in the County of Cornwall
# Yeoman deceased wha died 21 December
# 1857 at Egloshayle aforesaid was proved at
# Bodmin by the oath of Martha Williams
# (Wife of Edward Williams of the Parish of
# Luxullion in the said County) the sole
# Executrix.
#
# The Will
# of James Benjamin Artiss late of the Parish of
# Kenton in the County of Suffolk Draper
# deceased who died 17 March 1858 at St.
# Bartholomew’s Hospital London ‘was proved
# at the Principal Registry by the oath of
# Alfred Artiss of 1 Arlington-square Islington
# in the County of Middlesex Clerk to the
# Electric Telegraph Company Lothbury in the
# City of London the Brother and one of the
# Executors. -
#
#
#
#
# See ASHBRIDGE.
#
# The Will
# with a Codicil of William Asbury formerly
# of Park Hall Castle Bromwich in the Parish of
# Aston in the County of Warwick and late
# of Burbury-street in the said Parish of Aston
# Gentleman deceased who died 7 December
# 1857 at Burbury-street aforesaid was proved
# at Birmingham by the oaths of John
# Boucher of Harborne-road Edgbaston in the
# said County Gentleman and Richard Made-
# ley of Berwood House Erdington in the Parish
# of Aston aforesaid Gentleman the Executors.
#
# The Will
# of Elizabeth Ash late of Brixham in the
# County of Devon Widow deceased who
# died 6 February 1858 at Brixham aforesaid
# was proved at Exeter by the oaths of Char-
# lotte Ash and Elizabeth Shears Ash both of
# Brixham aforesaid Spinsters the Daughters
# and the Executrixes.
#
# The Will
# of Isaac Ash late of Checkley Bank in the
# Parish of Leigh in the County of Stafford
# Tape Weaver deceased, who died 16 March
# 1858 at Checkley Bank aforesaid was proved
# at Lichfield by the oaths of Jane Ash of
#
# uv
#
# tibet ye ae abt ae cee tata
#
# Checkley Bank aforesaid Widow the Relict

# %%
#re.compile('(\d+\s+(WILLS|ADMINISTRATIONS).\s+%s.){e<=2}')



for bod in b:
    try:
        abc = re.search(compiled, bod).group(0)
        print(abc)
    except:
        pass
# Out:
# Effects under £100.
# Effects under £200.
# Effects under £1,000,
# Effects under £100.
# Effects under £450.
# Effects under £3,000.

# %%
b
# Out:
# ['',
#  '',
#  'ASH Thomas.',
#  'Effects under £100.',
#  '',
#  'ASHBEE John.',
#  '',
#  'Effects under £200.',
#  '',
#  'Aart l8b0 . Under £300',
#  '',
#  'otherwise',
#  '',
#  'ASBRIDGE',
#  'Effects under £1,000,',
#  '',
#  'ASHBRIDGE',
#  ' Jane.',
#  '',
#  'ASHBURN William',
#  'Effects under £100.',
#  '',
#  'ASHBURNER Ann.',
#  'Effects under £450. -',
#  '',
#  'ASHBURNER John.',
#  'Effects under £3,000.',
#  '',
#  'and Charles Prince the younger of The Bents',
#  'near Tean in the same County Farmer the',
#  'Executors,',
#  '',
#  '2 October. The Will',
#  '',
#  'of Thomas Ash late of The Limpits in the',
#  'Parish of Whitmore in the County of Stafford',
#  'Farmer deceased who died 14 April 1847 at',
#  'The Limpits aforesaid was proved at Lich-',
#  'field by the oath of Isaac Watts, of Stonnall',
#  'in the Parish of Shenstone in the said County',
#  'Schoolmaster one of the Executors.',
#  '',
#  '27 February. The Will',
#  '',
#  'of John Ashbee late of Hawkesbury Upton',
#  'in the County of Gloucester Stonemason',
#  'deceased who died 2 January 1858 at Hawkes-',
#  'bury Upton aforesaid was proved at Glou-',
#  'cester by the oath of John Ashbee of the',
#  'Hamlet of Barton St. Mary in the said',
#  'County the Son and the sole Executor.',
#  '',
#  '10 June. The Will',
#  '',
#  'of Jane Ashbridge otherwise Asbridge formerly',
#  'of The Gill but late of Greensyke both in the',
#  'Parish of Dalston in the County of Cumber-',
#  'land Widow deceased who died 2 April',
#  '1858 at Greensyke aforesaid was proved at',
#  'Carlisle by the oaths of John Lawson of',
#  'The Gill aforesaid Farmer and James Nelson',
#  'of the City of Carlisle Marble Mason the',
#  'Executors.',
#  '',
#  '20 October. The Will',
#  '',
#  'of William Ashburn late of Milburn-street in',
#  'the City of Carlisle Shopkeeper deceased',
#  'who died 27 August 1856 at Milburn-street',
#  'aforesaid was proved at Carlisle by the oath',
#  'of Margaret Smith (Wife of Edward Smith',
#  'of the said City formerly Ashburn Widow)',
#  'the Relict and the sole Executrix.',
#  '',
#  '19 March. The Will',
#  '',
#  'of Ann Ashburner late of Soutergate in the',
#  'Parish of Kirkby Ireleth in the County of',
#  'Lancaster Spinster deceased who died',
#  '1 October 1857 at Soutergate aforesaid was',
#  'proved at Lancaster by the oath of Robert',
#  'Askew of Soutergate aforesaid Quarry Man the',
#  'sole Executor.',
#  '',
#  '9 March. The Will',
#  '',
#  'of John Ashburner late of Ulverston in the',
#  'County of Lancaster Ironmonger and',
#  'Zz',
#  '']

# %%
for p in clean_pages:
    # 1) PAGE METADATA
    ## - Split page metadata from body of page
    page, body = re.split(r'(?<= %s.)' % year, p, 1)
    
    # 2) NAME AND EFFECTS
    ## - Split by pound sign, which denotes split between N&E and biography
    ### If any pound values are in the thousands, remove the comma
    body = body.replace('?<=£\d+),(?=\d+)', '')
    ### Split names and effects from biographical information
    biog_str, name_str = re.split(r'(?r)(?<=£\d+\.)', body, 1)
    ### Split by person
    name_row = re.split('\n\n', name_str)
    ### Split name and effects by compiled string
    r = re.compile('^[A-Z]+(\s[A-Z][a-z]+)+\.')
    names_only = list(filter(r.match, name_row)) # Read Note
    names = [re.split('\n', n)[0] for n in names_only]
    effects = [re.split('\n', n)[1] for n in names_only]

    
    # 3) PROVED DATE
    ## Split proved date from biographical information
    dates_str, biog = re.split(r'\n(?=The Will)', biog_str, 1)
    dates_w_spaces = re.split('\n', dates_str)
    dates = list(filter(None, dates_w_spaces))
    
    # 4) BIOGRAPHY
    biog_split = re.split('\n\n', biog_str)
    biog_filter = re.compile('(^The Will)|Execut')
    biog_subset = list(filter(biog_filter.match, biog_split))
    biog_subset = [b.replace('-\n', '') for b in biog_subset]
    biography = [b.replace('\n', ' ') for b in biog_subset]
    
    if (biography[0].startswith('The Will')) == False:
        bio_from_prev_page = biography[0]
        biography = biography[1:]
    else:
        bio_from_prev_page = None
        
    check = len(biography) ==len(names_final) == len(effects) == len(dates) == len(biography)

    if check == True:
        print('okay')
    else:
        print('oops')
    
    fin = {'page': page, 'names': names, 'date': dates, 'effects': effects, 'biography': biography}
    res = pd.DataFrame(data = fin)
    df.append(res, ignore_index = True)
# Out:
# ----------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-17-3eeac8a3665c> in <module>
#      38         bio_from_prev_page = None
#      39
# ---> 40     check = len(biography) ==len(names_final) == len(effects) == len(dates) == len(biography)
#      41
#      42     if check == True:
#
# NameError: name 'names_final' is not defined

# %%
# 1) PAGE METADATA
## - Split page metadata from body of page

pages = []
bodies = []
for p in clean_pages[0]:
    page = re.search(r'(\d+ )?(WILLS. %s.)( \d+)?' % year, p).group(0)
    pages.append(page)
    body = re.sub(r'(\d+ )?(WILLS. %s.)( \d+)?' % year, '', p)
    bodies.append(body)
# Out:
# ----------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-18-3d7ccd53a0a2> in <module>
#       5 bodies = []
#       6 for p in clean_pages[0]:
# ----> 7     page = re.search(r'(\d+ )?(WILLS. %s.)( \d+)?' % year, p).group(0)
#       8     pages.append(page)
#       9     body = re.sub(r'(\d+ )?(WILLS. %s.)( \d+)?' % year, '', p)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
pages = []
bodies = []

for p in clean_pages:
    try:
        page = re.search(r'(\d+ )?((WILLS|ADMINISTRATIONS). %s.)( \d+)?' % year, p).group()
    except:
        try: 
            page = re.search(r'(\d+ )?([A-Z]+. %s.)( \d+)?' % year, p).group()
        except:    
            try:
                page = re.search(r'(\d+ )?( %s.)( \d+)?' % year, p).group()
            except:
                pass
    pages.append(page)

    
# body = re.sub(r'(\d+ )?([A-Z]+. %s.)( \d+)?' % year, '', p).group()    
# bodies.append(body)

pages
# Out:
# ['88 WILLS. 1858.',
#  'WILLS. 1858. 89',
#  '90 WILLS. 1858.',
#  'WILLS. 1858. 91',
#  'WILLS. 1858.',
#  'WILLS. 1858. 93',
#  '94 WILLS. 1858.',
#  'WILLS. 1858. 95',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  '98 WILLS. 1858.',
#  'WILLS. 1858. 99',
#  '100 WILLS. 1858.',
#  'WILLS. 1858. 101',
#  'WILLS. 1858. 7',
#  'WILLS. 1858. 103',
#  '104 WILLS. 1858.',
#  'WILLS. 1858. 105',
#  '106 WILLS. 1858.',
#  'WILLS. 1858. 107',
#  'WILLS. 1858.',
#  'WILLS. 1858. 109',
#  '110 WILLS. 1858.',
#  'WILLS. 1858. 111',
#  '112 WILLS. 1858.',
#  'WILLS. 1858. 113',
#  '114 WILLIS. 1858.',
#  'WILLS. 1858. 115',
#  'WILLS. 1858.',
#  'WILLS. 1858. 117',
#  '118 WILLS. 1858.',
#  'WILLS. 1858. 119',
#  'WILLS. 1858.',
#  ' 1858 ',
#  '122 WILLS 1858.',
#  'WILLS. 1858. 123',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 125',
#  '126 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 127',
#  '128 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 129',
#  '130 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 131',
#  'ADMINISTRATIONS. 1858,',
#  'ADMINISTRATIONS. 1858. 133',
#  '134 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 135',
#  '136 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 137',
#  '138 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS, 1858. 139',
#  '140 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 141',
#  'ADMINISTRATIONS 1858,',
#  'ADMINISTRATIONS. 1858. 143',
#  '144 ADMINISTRATIONS. 1858-',
#  'ADMINISTRATIONS, 1858, 145',
#  '146 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 147',
#  '148 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 149',
#  '150 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 151',
#  '152 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 153',
#  '154 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 155',
#  '156 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 157',
#  '158 ADMINISTRATIONS. 1858,',
#  'ADMINISTRATIONS. 1858. 159',
#  '160 ADMINISTRATIONS. 1858,',
#  'ADMINISTRATIONS. 1858. 161',
#  '162 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 163',
#  '164 ADMINISTRATIONS, 1858,',
#  'ADMINISTRATIONS. 1858. 165',
#  '166 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 167',
#  '168 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 169',
#  '170 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 17',
#  '172 ADMINISTRATIONS. 1858,',
#  'ADMINISTRATIONS. 1858. 173',
#  '174 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 175',
#  '176 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 177',
#  '178 ADMINISTRATIONS. 1858,',
#  'ADMINISTRATIONS. 1858. 179',
#  '180 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 18',
#  '182 ADMINISTRATIONS. 1858,',
#  'ADMINISTRATIONS. 1858. 183',
#  '184 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 185',
#  ' 1858 ',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858.',
#  '2 ADMINISTRATIONS, 1858.',
#  'ADMINISTRATIONS. 1858. 3',
#  '4 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 5',
#  ' 1858.',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858.',
#  '10 ADMINISTRATIONS. 1858.',
#  ' 1858.',
#  '12 ADMINISTRATIONS. 1858.',
#  ' 1858 ',
#  '14 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858, 45',
#  '16 ADMINISTRATIONS, 1858.',
#  'ADMINISTRATIONS. 1858. 17',
#  '18 ADMINISTRATIONS, 1858.',
#  'ADMINISTRATIONS. 1858.',
#  '20 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 21',
#  '29 ADMINISTRATIONS, 1858.',
#  'ADMINISTRATIONS. 1858. 23',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS 1858,',
#  '26 ADMINISTRATIONS. 1858.',
#  ' 1858 ',
#  ' 1858 ',
#  'ADMINISTRATIONS. 1858. 29',
#  '30 ADMINISTRATIONS. 1858.',
#  ' 1858. 3',
#  '32 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 33',
#  '34 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 35',
#  '36 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 37',
#  '38 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 39',
#  ' 1858-',
#  'ADMINISTRATIONS. 1858. 4',
#  '49 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 43',
#  ' 1858.',
#  'ADMINISTRATIONS. 1858. 45',
#  '46 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS, 1858.',
#  ' 1858 ',
#  'ADMINISTRATIONS. 1858. 49',
#  '50 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858.',
#  '52 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 53',
#  '54 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 55',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS, 1858. 57',
#  '58 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 59',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858 ',
#  '62 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 63',
#  '64 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 65',
#  ' 1858.',
#  'ADMINISTRATIONS, 1858. 67',
#  '68 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 69',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858, 71',
#  ' 1858.',
#  'ADMINISTRATIONS. 1858. 73',
#  '74 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 75',
#  '76 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 77',
#  ' 1858 ',
#  'ADMINISTRATIONS. 1858. 79',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 81',
#  '2 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 83',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS, 1858. 85',
#  '8 ADMINISTRATIONS. 1858.',
#  ' 1858. 87',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 89',
#  '90 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 9',
#  '99 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATEONS. 1858. 93',
#  '94 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 95',
#  '9 ADMINISTRATIONS 1858.',
#  'ADMINISTRATIONS. 1858. 97',
#  'ISTRATIONS. 1858.',
#  ' 1858 ',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858, 101',
#  '102 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858.',
#  '104 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 105',
#  ' 1858 ',
#  ' 1858. 107',
#  '108 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858.',
#  '10 ADMINISTRATIONS, 1858.',
#  'ADMINISTRATIONS. 1858. 111',
#  '12 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 113',
#  '114 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 115',
#  '116 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858.',
#  '118 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS, 1858 ',
#  ' 1858.',
#  'ADMINISTRATIONS. 1858, 121',
#  '12 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS, 1858. 123',
#  '124 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858.',
#  ' 1858 ',
#  'ADMINISTRATIONS. 1858. 127',
#  '128 ADMINISTRATIONS 1858.',
#  'ADMINISTRATIONS. 1858.',
#  '130 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 131',
#  '139 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 133',
#  '134 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 135',
#  '136 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 137',
#  '138 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 139',
#  '140 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS, 1858. 141',
#  '142 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 143',
#  ' 1858 ',
#  ' 1858 ',
#  '146 ADMINISTRATIONS 1858,',
#  'ADMINISTRATIONS. 1858. 147',
#  '148 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 14',
#  ' 1858.',
#  'ADMINISTRATIONS, 1858. 151',
#  '12 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858, 158',
#  '154 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS, 1858. 155',
#  ' 1858.',
#  'ADMINISTRATIONS. 1858. 157',
#  '158 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 159',
#  '160 ADMINISTRATIONS. 1858.',
#  ' 1858. 161',
#  '162 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 163',
#  ' 1858 ',
#  'ADMINISTRATIONS. 1858. 165',
#  '166 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 167',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858.',
#  ' 1858.',
#  'ADMINISTRATIONS. 1858. 171',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 173',
#  '14 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS, 1858.',
#  '176 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 177',
#  '178 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 179',
#  '180 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858.',
#  '182 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 183',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 185',
#  '186 ADMINISTRATIONS 1858.',
#  ' 1858. 187',
#  '188 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 189',
#  'ADMINISTRATIONS. 1858.',
#  ' 1858 ',
#  '192 ADMINISTRATIONS. 1858,',
#  'ADMINISTRATIONS, 1858. 198',
#  'ADMINISTRATIONS, 1858.',
#  'ADMINISTRATIONS, 1858. 195',
#  'ADMINISTRATIONS. 1858,',
#  ' 1858.',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858.',
#  '200 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 201',
#  '202 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 203',
#  '14 WILLS. 1858.',
#  'WILLS. 1858. 115',
#  ' 1858.',
#  'WILLS 1858.',
#  ' 1858.',
#  ' 1858 ',
#  ' 1858.',
#  ' 1858. 121',
#  ' 1858.',
#  'WILLS. 1858. 123',
#  'WILLS. 1858.',
#  'WILLS. 1858. 195',
#  '126 WILLS. 1858.',
#  'WILLS. 1858. 127',
#  'WILLS. 1858.',
#  'WILLS. 1858. 129',
#  'WILLS. 1858.',
#  'WILLS. 1858. 131',
#  ' 1858 ',
#  ' 1858 ',
#  ' 1858.',
#  ' 1858. 135',
#  ' 1858 ',
#  ' 1858. 137',
#  '38 WILLS. 1858.',
#  'WILLS. 1858 ',
#  '140 WILLS. 1858.',
#  ' 1858 ',
#  ' 1858 ',
#  'WILLS 1858. 143',
#  'WILLS. 1858.',
#  'WILLS. 1858. 145',
#  '146 WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 149',
#  '150 WILLS. 1858.',
#  'WILLS. 1858. 151',
#  'WILLS. 1858.',
#  'WILLS. 1858. 153',
#  ' 1858 ',
#  'WILLS. 1858 ',
#  ' 1858 ',
#  ' 1858. 157',
#  ' 1858 ',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  '162 WILLS. 1858.',
#  'WILLS. 1858. 163',
#  '164 WILLS. 1858.',
#  'WILLS. 1858. 165',
#  'WILLS. 1858.',
#  'WILLS. 1858. 167',
#  '168 WILLS. 1858.',
#  ' 1858. 169',
#  '170 WILLS. 1858.',
#  'WILLS 1858.',
#  ' 1858 ',
#  'WILLS. 1858 ',
#  'WILLS, 1858.',
#  ' 1858 ',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 179',
#  'WILLS. 1858.',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  ' 1858.',
#  'WILLS. 1858. 185',
#  ' 1858 ',
#  'WILLS. 1858.',
#  '188 WILLS. 1858.',
#  'WILLS. 1858. 189',
#  '190 WILLS. 1858.',
#  ' 1858 ',
#  'WILLS. 1858.',
#  ' 1858 ',
#  '194 WILLS. 1858.',
#  'WILLS 1858. 195',
#  'WILLS. 1858.',
#  'S. 1858. 197',
#  '198 WILLS. 1858.',
#  'WILLS. 1858. 199',
#  'WILLS. 1858.',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858. 203',
#  ' 1858.',
#  'WILLS. 1858. 205',
#  '206 WILLS. 1858.',
#  'WILLS. 1858. 207',
#  '208 WILLS. 1858.',
#  'WILLS. 1858. 209',
#  '210 WILLS. 1858.',
#  'WILLS. 1858.',
#  '212 WILLS. 1858.',
#  ' 1858. 213',
#  'WILLS. 1858.',
#  'WILLS. 1858. 215',
#  'WILLS. 1858.',
#  'WILLS. 1858. 217',
#  '218 WILLS. 1858.',
#  'WILLS. 1858. 219',
#  'WILLS. 1858.',
#  'WEELS 1858. 221',
#  ' 1858.',
#  'WILLS. 1858. 223',
#  ' 1858 ',
#  ' 1858 ',
#  '226 WILLS. 1858.',
#  'WILLS. 1858. 297',
#  ' 1858.',
#  'WILLS. 1858.',
#  ' 1858 ',
#  'WILLS. 1858. 3',
#  ' 1858 ',
#  'WILLS. 1858. 5',
#  'WILLS 1858.',
#  'WILLS. 1858. 7',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 11',
#  'WILLS. 1858.',
#  'WILLS. 1858. 23',
#  'WILLS. 1858.',
#  'WILLS. 1858. 15',
#  '16 WILLS. 1858.',
#  ' 1858 ',
#  '18 WILLS. 1858.',
#  ' 1858 ',
#  '20 WILLS. 1858.',
#  'WILLS. 1858 ',
#  '99 WILLS. 1858.',
#  'WILLS. 1858. 23',
#  'WILLS. 1858.',
#  ' 1858 ',
#  '26 WILLS. 1858.',
#  'WILLS. 1858. 27',
#  '98 WILLS. 1858.',
#  'WILLS. 1858. 29',
#  '30 WILLS. 1858.',
#  'WILLS. 1858. 31',
#  '32 WILLS. 1858.',
#  'WILLS. 1858. 33',
#  '34 WILLS. 1858.',
#  'WILLS. 1858. 35',
#  '360 WILLS. 1858.',
#  'WILLS. 1858. 87',
#  ' 1858 ',
#  ' 1858 ',
#  ' 1858 ',
#  'WILLS. 1858 ',
#  'WILLS. 1858.',
#  '7 WILLS. 1858.',
#  ' 1858 ',
#  'WILLS. 1858. 45',
#  'WILLS. 1858.',
#  'WILLS. 1858. 47',
#  'WILIS. 1858.',
#  'WILLS. 1858. 49',
#  '50 WILLS. 1858.',
#  'WILLS. 1858. 51',
#  'WILLS. 1858.',
#  'WILLS, 1858. 5',
#  '64 WILLS. 1858.',
#  'WILLS. 1858. 55',
#  '56 WILLS. 1858.',
#  'WILLS. 1858. 57',
#  '58 WILLS. 1858.',
#  'WILLS. 1858. 59',
#  '60 WILLS. 1858.',
#  'WILLS. 1858. 61',
#  '62 WILLS. 1858.',
#  'WILLS. 1858. 63',
#  '64 WILLS. 1858.',
#  'WILLIS. 1858. 65',
#  '66 WILLS. 1858.',
#  'WILLS. 1858. 67',
#  'WILLS. 1858.',
#  'WILLS. 1858. 69',
#  'WILLS. 1858.',
#  'WILLS. 1858. 7',
#  'WILLS. 1858.',
#  'WILLS 1858. 73',
#  '74 WILLS. 1858.',
#  'WILLS. 1858,',
#  '76 WILLS. 1858.',
#  'WILLS. 1858.',
#  '78 WILLS. 1858.',
#  'WILLS. 1858. 79',
#  '80 WILLS. 1858.',
#  'WILLS. 1858. 8',
#  'WILLS. 1858.',
#  'WILLS. 1858. 83',
#  '84 WILLS. 1858.',
#  ' 1858. 85',
#  '86 WILLS. 1858.',
#  'WILLS. 1858. 87',
#  '88 WILLS. 1858.',
#  'WILLS. 1858. 89',
#  ' 1858 ',
#  'WILLS. 1858. 91',
#  '92 WILLS. 1858.',
#  ' 1858 ',
#  '4 WILLS 1858.',
#  'WILLS. 1858. 95',
#  ' 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 99',
#  '00 WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 103',
#  ' 1858 ',
#  'WILLS. 1858. 105',
#  'WILLS. 1858.',
#  'WILLS. 1858. 107',
#  '108 WILLS. 1858.',
#  'WILLS. 1858. 109',
#  '110 WILLS. 1858.',
#  'WILLS. 1858. 11',
#  '2 WILLS. 1858.',
#  'WILLS. 1858. 113',
#  'WILLS. 1858.',
#  ' 1858 ',
#  '116 WILLS. 1858.',
#  'WILLS. 1858. 7',
#  '118 WILLIS. 1858.',
#  'WILLS. 1858. 119',
#  'WILLS. 1858.',
#  'WILLS. 1858. 121',
#  'WILLS. 1858.',
#  'WILLS. 1858. 123',
#  'WILLS. 1858.',
#  'WILLS. 1858. 135',
#  ' 1858 ',
#  'WILLS. 1858. 197',
#  ' 1858 ',
#  'WILLS. 1858. 129',
#  '130 WILLS 1858.',
#  ' 1858 ',
#  ' 1858 ',
#  ' 1858 ',
#  '134 WILLS. 1858.',
#  'WILLS. 1858. 135',
#  '136 WILLS. 1858.',
#  'WILLS. 1858. 137',
#  '138 WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  ' 1858.',
#  ' 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 147',
#  '148 WILLS. 1858.',
#  'WILLS. 1858. 149',
#  '150 WILLS. 1858.',
#  'WILLS. 1858. 151',
#  '152 WILLS. 1858.',
#  'WILLS. 1858. 153',
#  '154 WILLS. 1858.',
#  'WILLS. 1858. 155',
#  '156 WILLS. 1858.',
#  'WILLS. 1858. 187',
#  'WILLS. 1858.',
#  ' 1858. 159',
#  '160 WILLS. 1858.',
#  'WILLS. 1858.',
#  '162 WILLS. 1858.',
#  ' 1858 ',
#  '164 WILLS. 1858.',
#  ' 1858 ',
#  '166 WILLS. 1858.',
#  'WILLS. 1858. 167',
#  '168 WILLS. 1858 ',
#  'WIELSS 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858. 171',
#  '2 WILLS. 1858.',
#  'WILLS. 1858. 173',
#  ' 1858 ',
#  'WILLS. 1858. 175',
#  ' 1858 ',
#  'WILLS. 1858.',
#  '178 WILLS. 1858.',
#  'WILLS. 1858. 179',
#  '180 WILLS. 1858.',
#  'WILLS. 1858. 181',
#  'WILLS. 1858.',
#  'WILLS. 1858 ',
#  '184 WILLS. 1858.',
#  'WILLS. 1858.',
#  '186 WILLS. 1858.',
#  ' 1858 ',
#  ' 1858 ',
#  'WILLS. 1858. 189',
#  '190 WILLS. 1858.',
#  'WILLS. 1858. 191',
#  '192 WILLS. 1858.',
#  'WILLS. 1858. 193',
#  'WILLS. 1858.',
#  'WILLS. 1858. 195',
#  ' 1858.',
#  ' 1858. 197',
#  ' 1858 ',
#  'WILLS 1858. 199',
#  'WILLS. 1858.',
#  'WILLS. 1858. 201',
#  'WILLS 1858.',
#  'WILLS. 1858-',
#  ' 1858 ',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858. 207',
#  '208 WILLIS. 1858.',
#  ' 1858 ',
#  '210 WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  ' 1858 ',
#  '4 WILLS. 1858.',
#  'WILLS. 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858. 87',
#  '218 WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 221',
#  '229 WILLS. 1858.',
#  ' 1858 ',
#  ' 1858 ',
#  ' 1858 ',
#  '226 WILLS. 1858,',
#  '226 WILLS. 1858,',
#  'WILLS. 1858.',
#  '20 WILLS. 1858.',
#  'WILLS. 1858. 3',
#  '4 WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 7',
#  'WILLS. 1858.',
#  ' 1858 ',
#  '10 WILLS. 1858.',
#  ' 1858 ',
#  '12 WILLS. 1858.',
#  ' 1858. 13',
#  'WILLS 1858.',
#  'WILLS. 1858. 13',
#  '16 WILLS. 1858.',
#  ' 1858 ',
#  ' 1858 ',
#  'WILLS. 1858.',
#  '20 WILLS. 1858.',
#  'WIELS. 1858. 21',
#  'WILLS. 1858.',
#  'WILLS. 1858. 23',
#  '24 WILLS. 1858.',
#  'WILLS. 1858. 95',
#  '2600 WILLS. 1858.',
#  'WILLS. 1858. 27',
#  '2 WILLS. 1858.',
#  'WILLS. 1858. 29',
#  ' 1858.',
#  'WILLS. 1858. 31',
#  'WILLS. 1858.',
#  'WILLS. 1858. 33',
#  ' 1858.',
#  'WILLS. 1858. 35',
#  ' 1858 ',
#  ' 1858. 37',
#  ' 1858.',
#  'WILLS. 1858. 39',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 43',
#  '44 WILLS. 1858.',
#  'WILLS. 1858. 45',
#  '46 WILLS. 1858.',
#  'WILLS. 1858. 47',
#  ' 1858.',
#  'WILLS. 1858. 4',
#  'WILLS. 1858.',
#  'WILLS. 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  '0 WELLS. 1858.',
#  'WILLS. 1858.',
#  ' 1858 ',
#  'WILLS. 1858.',
#  ' 1858.',
#  'WILLS. 18588',
#  'WILLS. 1858.',
#  'WILLS. 1858. 61',
#  'WILLS. 1858.',
#  'WILLS. 1858. 63',
#  '64 WILLS. 1858.',
#  'WILLS. 1858. 65',
#  'WILLS. 1858.',
#  ' 1858 ',
#  'WILLS. 1858.',
#  ' 1858. 69',
#  'WILLS. 1858.',
#  'WILLS. 1858. 71',
#  ' 1858 ',
#  ' 1858.',
#  '74 WILLS. 1858.',
#  'WILLS 1858. 75',
#  '76 WILLS. 1858.',
#  'WILLS. 1858.',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 81',
#  '69 WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 85',
#  '86 WILLS. 1858.',
#  'WILLS. 1858.',
#  '88 WILLS. 1858.',
#  'WILLS. 1858. 89',
#  ' 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  ' 1858 ',
#  '94 WILLS. 1858.',
#  ' 1858. 95',
#  'WILLS. 1858.',
#  'WILLS 1858.',
#  '98 WILLS. 1858.',
#  'WILLS. 1858. 99',
#  ' 1858 ',
#  'WILLS. 1858. 101',
#  '102 WILLS. 1858.',
#  'WILLS. 1858. 103',
#  '104 WILLS. 1858.',
#  ' 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 107',
#  '108 WILLS. 1858.',
#  'WILLS. 1858. 109',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 113',
#  '14 WILLS. 1858.',
#  'WILLS. 1858. 115',
#  ' 1858.',
#  'WILLS. 1858. 117',
#  'WILLS. 1858.',
#  'WILLS 1858 ',
#  '120 WILLS. 1858.',
#  'WILLS. 1858 ',
#  '122 WILLS. 1858.',
#  'WILLS. 1858. 123',
#  ' 1858.',
#  ' 1858.',
#  '126 WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 129',
#  ' 1858 ',
#  'WILLS. 1858. 13',
#  ' 1858 ',
#  'WILLS. 1858.',
#  ' 1858.',
#  'WILLS. 1858. 35',
#  '136 WILLS. 1858.',
#  'WILLS. 1858. 137',
#  '138 WILLS. 1858.',
#  'WILLS. 1858.',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS 1858.',
#  'WILLS. 1858,',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858. 147',
#  '148 WILLS. 1858.',
#  ' 1858, 149',
#  '130 WILLS. 1858.',
#  'WILLS. 1858. 151',
#  ' 1858.',
#  'WILLS. 1858. 153',
#  '154 WILLS. 1858,',
#  'WILLS. 1858. 155',
#  ' 1858 ',
#  'WILLS. 1858. 157',
#  '158 WILLS. 1858.',
#  'WILLS. 1858. 159',
#  '160 WILLS 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  ' 1858 ',
#  'WILLS 1858. 165',
#  'WILLS. 1858.',
#  'WILLS. 1858)',
#  'WILLS. 1858.',
#  'WILLS. 1858. 169',
#  '170 WILLS. 1858.',
#  'WILLS. 1858. 171',
#  'WILLS. 1858.',
#  'WILLS. 1858. 173',
#  ' 1858 ',
#  'WILLS. 1858. 175',
#  '176 WILLS. 1858.',
#  'WILLS. 1858. 177',
#  '178 WILLS. 1858.',
#  'WILLS. 1858. 179',
#  ' 1858 ',
#  'WILLS. 1858. 181',
#  '182 WILLS. 1858.',
#  'WILLS. 1858. 183',
#  '184 WILLS. 1858.',
#  'WILLS. 1858. 1',
#  '186 WILLS. 1858.',
#  ' 1858 ',
#  'WILLS, 1858.',
#  ' 1858 ',
#  '190 WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 193',
#  '194 WILLS. 1858.',
#  'WILLS. 1858.',
#  '198 WILLS 1858,',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858. 199',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858. 205',
#  'WILLS. 1858.',
#  'WILLS. 1858, 207',
#  '208 WILLS. 1858.',
#  'WILLS. 1858. 209',
#  ' 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 213',
#  ' 1858 ',
#  'WILLS. 1858.',
#  ' 1858.',
#  'WILLS 1858. 217',
#  '218 WILLS. 1858.',
#  'WILLS. 1858. 219',
#  '20 WILLS. 1858.',
#  'WILLS. 1858. 99',
#  ' 1858 ',
#  'WILLS. 1858. 223',
#  'WILLS. 1858.',
#  'WILLS. 1858 ',
#  '2 WILLS. 1858.',
#  'WILLS. 1858. 3',
#  'WILLS. 1858.',
#  'WILLS. 1858. 5',
#  ' 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  '10 WILLS. 1858.',
#  'WILLS. 1858.',
#  '12 WILLS. 1858.',
#  'WILLS. 1858. 13',
#  'WILLS 1858.',
#  'WELLS. 1858.',
#  '16 WILLS. 1858.',
#  ' 1858 ',
#  ' 1858.',
#  'WILLS. 1858. 19',
#  '0 WALLS. 1858.',
#  'WILLS. 1858.',
#  '22 WILLS. 1858.',
#  'WILLS. 1858. 23',
#  'WILLS. 1858.',
#  'WILLS. 1858. 25',
#  '96 WILLS. 1858.',
#  'WILLS. 1858. 27',
#  'WILLS. 1858.',
#  'WALLIS. 1858. 29',
#  '30 WILLS. 1858.',
#  'WILLS. 1858. 31',
#  'WILLS 1858,',
#  'WILLS. 1858. 33',
#  'WILLS. 1858.',
#  'WILLS. 1858. 35',
#  ' 1858 ',
#  'WILLS. 1858. 37',
#  'WILLS. 1858.',
#  'WILLS. 1858. 39',
#  '40 WILLS. 1858.',
#  'WILLS. 1858. 4',
#  '42 WILLS. 1858.',
#  'WILLS. 1858, 4',
#  ' 1858 ',
#  ' 1858 ',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  '48 WILLS. 1858.',
#  'WILLS 1858. 49',
#  'WILLS. 1858.',
#  'WILLS. 1858.',
#  '52 WILLS. 1858.',
#  ' 1858 ',
#  '54 WILLS. 1858.',
#  'WILLS. 1858. 55',
#  'WILLS. 1858.',
#  'WILLS. 1858. 57',
#  '58 WILLS. 1858.',
#  'WILLS. 1858.',
#  'WLLLS. 1858.',
#  'WILLS. 1858. 61',
#  'WILLS. 1858.',
#  'WILLS. 1858. 63',
#  ' 1858.',
#  'WILLS. 1858. 6',
#  '66 WILLS. 1858.',
#  'WILLS. 1858. 67',
#  'WILLS. 1858.',
#  ' 1858. 69',
#  'WILLS. 1858.',
#  'WILLS. 1858. 71',
#  'WILLS. 1858.',
#  'WILLS 1858.',
#  'WILLS. 1858.',
#  'WILLS. 1858. 75',
#  ' 1858 ',
#  'WILLS. 1858. 77',
#  '78 WILLS. 1858.',
#  'WILLS. 1858. 79',
#  '80 WILLS. 1858.',
#  'WILLS. 1858. 81',
#  ' 1858 ',
#  'WILLS. 1858.',
#  '84 WILLS. 1858.',
#  'WILLS. 1858. 85',
#  'WILLS. 1858.',
#  '116 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858 ',
#  '118 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858.',
#  '120 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 121',
#  '129 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 123',
#  '124 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS, 1858 ',
#  '126 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 197',
#  '198 ADMINISTRATIONS 1858.',
#  'ADMINISTRATIONS 1858. 129',
#  ' 1858 ',
#  ' 1858 ',
#  ' 1858.',
#  ' 1858. 133',
#  ' 1858 ',
#  'ADMINISTRATIONS. 1858. 135',
#  '136 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS, 1858. 137',
#  ' 1858.',
#  'ADMINISTRATIONS. 1858, 139',
#  ' 1858.',
#  'ADMINISTRATIONS. 1858. 141',
#  '142 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 143',
#  'ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 145',
#  'ADMINISTRATIONS, 1858.',
#  'ADMINISTRATIONS. 1858. 147',
#  '146 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 149',
#  ' 1858,',
#  'ADMINISTRATIONS. 1858. 151',
#  '152 ADMINISTRATIONS. 1858.',
#  'ADMINISTRATIONS. 1858. 153',
#  ' 1858 ',
#  'ADMINISTRATIONS. 1858.',
#  ' 1858.',
#  'ADMINISTRATIONS. 1858. 157',
#  'ADMINISTRATIONS. 1858. 157',
#  'ADMINISTRATIONS. 1858. 139',
#  ' 1858 ',
#  ...]

# %%
[i for i in range(len(pages)) if pages[i] == None]
clean_pages[33]
# Out:
# 'WILLS.\n\nAYLMER Thomas Brabazon. Eset 4 Aug\nEffects under £40,000.\n\n1858. 121\n\nthe oaths of George Lake Russell of Lincoln’s\nInn in the said County Esquire Barrister-at-\nlaw and Charles Brune Graves Sawle of\n\nRestormel in the County of Cornwall Esquire \n\nthe Executors.\n\nust, The Will\n\nof Thomas Brabazon Aylmer late of Worthing\nin the County of Sussex Esquire a General\nin H. M. Army deceased who died 19 July\n1858 at Worthing aforesaid was proved at the\nPrincipal Registry. by the oaths of\nThomas Brabazon Aylmer of Congresbury in\nthe County of Somerset and George Edward\nAylmer of the United Service Club Pall Mall\nin the County of Middlesex Esquires the Sons\nand the Executors.\n\nAYNSLEY Lionel. 5 November. Letters of Administration\n\nEffects under £20.\n\n(with the Will annexed) of the Personal estate\nand effects of Lionel Aynsley late of Churm\nin the Parish of Longhorsley in the County\nof Northumberland deceased who died\n3 May 1829 at Churm aforesaid left unad-\nministered by John Tindle and John Lennox\nthe Executors named in the said Will were\ngranted at the Principal Registry to\nJohn Aynsley of Chevington Woodside in\nthe said County Farmer the Grandson and\none of the Universal Legatees named in\nthe said Will he having been first sworn\nFormer grant Consistory Court of Durham\nDecember 1829.\n\nAYRES Elizabeth. 30 June. The Will\n\nEffects under £8,000.\n\nof Elizabeth Ayres late of Heath Mount\nCottage Hampstead in the County of Mid-\ndlesex Widow deceased who died 10 June\n1858 at Heath Mount Cottage aforesaid was\nproved at the Principal Registry by the\noaths of Charles Ayres of High-street Hamp-\nstead aforesaid Livery Stable Keeper and\nJames Smith of Rock Cottage Hampstead\naforesaid Gentleman the Executors.\n\nAYRES Thomas. 6 March. The Will\n\nEffects under £100.\n\nof Thomas Ayres late of Buckingham in the\nCounty of Buckingham deceased who\ndied 28 January 1858 at Buckingham afore-\nsaid was proved at the Principal Registry\nby the oaths of Mary Ayres of Buckingham\naforesaid Widow the Relict and William\nStuchbery of the same place Butcher the\nExecutors.\nHA\n\n’ \n4\nLf f J\n'

# %%
# 2) NAME AND EFFECTS
## - Split by pound sign, which denotes split between N&E and biography
### If any pound values are in the thousands, remove the comma
body = body.replace('?<=£\d+),(?=\d+)', '')
### Split names and effects from biographical information
biog_str, name_str = re.split(r'(?r)(?<=£\d+\.)', body, 1)
### Split by person
name_row = re.split('\n\n', name_str)
### Split name and effects by compiled string
r = re.compile('^[A-Z]+(\s[A-Z][a-z]+)+\.')
names_only = list(filter(r.match, name_row)) # Read Note
names = [re.split('\n', n)[0] for n in names_only]
effects = [re.split('\n', n)[1] for n in names_only]

# %%
# 3) PROVED DATE
## Split proved date from biographical information
dates_str, biog = re.split(r'\n(?=The Will)', biog_str, 1)
dates_w_spaces = re.split('\n', dates_str)
dates = list(filter(None, dates_w_spaces))

# %%
# 4) BIOGRAPHY
biog_split = re.split('\n\n', biog_str)
biog_filter = re.compile('(^The Will)|Execut')
biog_subset = list(filter(biog_filter.match, biog_split))
biog_subset = [b.replace('-\n', '') for b in biog_subset]
biography = [b.replace('\n', ' ') for b in biog_subset]

# %%
if (biography[0].startswith('The Will')) == False:
    bio_from_prev_page = biography[0]
    biography = biography[1:]
else:
    bio_from_prev_page = None

check = len(biography) ==len(names_final) == len(effects) == len(dates) == len(biography)

if check == True:
    print('okay')
else:
    print('oops')

# %%
#Create empty data frame so that I can store the output from regex
df = pd.DataFrame(columns=['page', 'names', 'date', 'effects', 'biography'])
fin = {'page': page, 'names': names, 'date': dates, 'effects': effects, 'biography': biography}
res = pd.DataFrame(data = fin)
df.append(res, ignore_index = True)
